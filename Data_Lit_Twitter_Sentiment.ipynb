# %%
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.18.4)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.11.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.2.1)

# %%
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

# %%
import re
def clean_tweet(tweet):
  return ''.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)",' ',tweet).split())

# %%
tweets = api.search('Online Education',count = 2500)
data = pd.DataFrame(data = [tweet.text for tweet in tweets],columns = ['Tweets'])
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @UK_SIC: Whether you have 10 minutes or a w...
# 1  RT @amnistia: Con el nuevo curso de Amnistía I...
# 2  RT @central_cap: Trudeau, Butts &amp; Hussen b...
# 3  RT @CommonSenseEd: When Ss go online, whether ...
# 4  Millions of kids around the world dream of bet...
# 5  RT @page_eco: A warning for the push towards o...
# 6  When Ss go online, whether they're playing mul...
# 7  RT @OpogoEducation: Next Tuesday 5 February 20...
# 8  This is a nice opinion piece about quality of ...
# 9  [Inside #HigherEd #DigitalLearning]: Philosoph...

# %%
import nltk
nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()
list_for_polarity = []
for index,row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  list_for_polarity.append(ss)
  
se = pd.Series(list_for_polarity)
data['polarity'] = se.values

display(data.head(1000))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                                Tweets  \
# 0   RT @UK_SIC: Whether you have 10 minutes or a w...
# 1   RT @amnistia: Con el nuevo curso de Amnistía I...
# 2   RT @central_cap: Trudeau, Butts &amp; Hussen b...
# 3   RT @CommonSenseEd: When Ss go online, whether ...
# 4   Millions of kids around the world dream of bet...
# 5   RT @page_eco: A warning for the push towards o...
# 6   When Ss go online, whether they're playing mul...
# 7   RT @OpogoEducation: Next Tuesday 5 February 20...
# 8   This is a nice opinion piece about quality of ...
# 9   [Inside #HigherEd #DigitalLearning]: Philosoph...
# 10  Philosophical (Not Financial) Drivers of Onlin...
# 11  Free Online Bookkeeping Course #9 – Closing T ...
# 12  Free Online Bookkeeping Course #9 – Closing T ...
# 13  Free Online Bookkeeping Course #9 – Closing T ...
# 14  RT @Humanists_UK: TAKE ACTION: The Department ...
# 15  RT @BerkeleyLaw: Congrats to @BerkLawBusiness ...
# 16  @caroljsroth @billmiller6600 Coursework availa...
# 17  @WhiteHouse worldwide education goes online ht...
# 18  Yes, #elearning brings challenges, but there a...
# 19  RT @abbiedigital: @bbcbigquestions parents nee...
# 20  Next Tuesday 5 February 2019, join @Gangology ...
# 21  Look what Charlie Kirk has done for himself wi...
# 22  RT @eraser: Vol 14, No 11 (2018) International...
# 23  RT @central_cap: Trudeau, Butts &amp; Hussen b...
# 24  Online Education: Posture Rehab Course - DC, M...
# 25  RT @central_cap: Trudeau, Butts &amp; Hussen b...
# 26  RT @NCCAie: The review of Relationships and Se...
# 27  RT @NCCAie: The review of Relationships and Se...
# 28  Vol 14, No 11 (2018) International Journal of ...
# 29  @PMOIndia @narendramodi @PiyushGoyal @arunjait...
# ..                                                ...
# 70  RT @ISE_Show: It’s the final countdown  #ISE20...
# 71  RT @ArchivesOntario: February is #BlackHistory...
# 72  RT @arjunmodhwadia: NoMo Job report:\n\nTotal ...
# 73  RT @myPD247: #LAEDCHAT is Louisiana's educatio...
# 74  VOD: February 1, 2019 @RCS_NC Board Of Educati...
# 75  #LAEDCHAT is Louisiana's education chat that t...
# 76  RT @nikdoig: Super exciting! The Use &amp; Car...
# 77  Millions of kids around the world dream of bet...
# 78  RT @subrahyd: UGC allows all higher edu instit...
# 79  CSW Online works to organise Speedwatch scheme...
# 80  Make significant cost savings for your school ...
# 81  RT @camscience: Online listings are now live! ...
# 82  RT @GaiaEducation: The Power of Community Summ...
# 83  Millions of kids around the world dream of bet...
# 84  RT @Abiaonline1: Live on Abia Online: Ngwa Wom...
# 85  I am a blogger and also a nonprofit education ...
# 86  RT @CITeachED: Join us @KingsECS in London for...
# 87  RT @ahmedjr_16: 22 Best #Teacher #Training #To...
# 88  RT @Humanists_UK: TAKE ACTION: The Department ...
# 89  RT @Alex_Corbitt: 13 Online Study Tools 📖⏱📱💡 (...
# 90  RT @Humanists_UK: TAKE ACTION: The Department ...
# 91  RT @amnistia: Con el nuevo curso de Amnistía I...
# 92  Academic Director Vacancy - Hluboka nad Vltavo...
# 93  RT @amnistia: Con el nuevo curso de Amnistía I...
# 94                            https://t.co/PsQ8y2BNoH
# 95  RT @ISE_Show: It’s the final countdown  #ISE20...
# 96  KEAM 2019: Online application process begins\n...
# 97  RT @StatGarrett: Hands-On Programming with R i...
# 98  RT @CEOPUK: What are your plans for #SaferInte...
# 99  RT @Humanists_UK: TAKE ACTION: The Department ...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'comp...
# 4   {'neg': 0.112, 'neu': 0.543, 'pos': 0.346, 'co...
# 5   {'neg': 0.263, 'neu': 0.737, 'pos': 0.0, 'comp...
# 6   {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...
# 7   {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'comp...
# 8   {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'comp...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'comp...
# 12  {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'comp...
# 13  {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'comp...
# 14  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...
# 15  {'neg': 0.0, 'neu': 0.717, 'pos': 0.283, 'comp...
# 16  {'neg': 0.219, 'neu': 0.71, 'pos': 0.071, 'com...
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'comp...
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20  {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound...
# 21  {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'comp...
# 22  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'comp...
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'comp...
# 29  {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'comp...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compou...
# 71  {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'comp...
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 73  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 74  {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'comp...
# 75  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 76  {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'comp...
# 77  {'neg': 0.112, 'neu': 0.543, 'pos': 0.346, 'co...
# 78  {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'comp...
# 79  {'neg': 0.115, 'neu': 0.824, 'pos': 0.06, 'com...
# 80  {'neg': 0.0, 'neu': 0.709, 'pos': 0.291, 'comp...
# 81  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 82  {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'comp...
# 83  {'neg': 0.112, 'neu': 0.543, 'pos': 0.346, 'co...
# 84  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 85  {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'comp...
# 86  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'comp...
# 87  {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'comp...
# 88  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...
# 91  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 95  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compou...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 0.651, 'pos': 0.349, 'comp...
# 98  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'comp...
# 99  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'comp...
#
# [100 rows x 2 columns]
